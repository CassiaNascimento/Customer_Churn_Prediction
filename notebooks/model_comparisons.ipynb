# %%
from load_data import load_raw_data
from clean_data import clean_data
from split_data import split_data
from build_pipeline import build_pipeline
from evaluate_model import evaluate_model
from config import CHURN_MODEL_PATH, RANDOM_STATE, MODEL_PATH
import joblib
import logging
from pathlib import Path

# %%
logging.basicConfig(
    level=logging.INFO,format="%(asctime)s | %(levelname)s | %(name)s | %(message)s")

# %%
# Loading raw data
dataset=load_raw_data()
# Out:
# 2026-05-22 23:19:57,728 | INFO | load_data | Raw dataset loaded.

# %%
# Cleaning data
dataset_cleaned=clean_data(dataset)
# Out:
# 2026-05-22 23:19:57,732 | INFO | clean_data | Dropped customerID.
# 2026-05-22 23:19:57,735 | INFO | clean_data | Converted TotalCharges to numeric.
# 2026-05-22 23:19:57,739 | INFO | clean_data | Rows containing NaN before cleaning: 11
# 2026-05-22 23:19:57,745 | INFO | clean_data | Removed 11 rows with invalid TotalCharges. Remaining rows with NaN: 0.

# %%
# Splitting data
X_train, X_test, y_train, y_test=split_data(dataset_cleaned, random_state=RANDOM_STATE)
# Out:
# 2026-05-22 23:19:57,755 | INFO | split_data | Data split into train/test set with 0.8/0.2 proportion and random_state=0.

# %%
# Building Logistic Regression model
pipe_LR=build_pipeline('Logistic Regression')
fitted_pipe_LR=pipe_LR.fit(X_train, y_train)
# Out:
# 2026-05-22 23:19:57,758 | INFO | build_pipeline | Pipeline (encoder, scaler, classifier) created for model: Logistic Regression.

# %%
# Building K-Nearest Neighbors
pipe_KNN=build_pipeline('K-Nearest Neighbors')
fitted_pipe_KNN=pipe_KNN.fit(X_train, y_train)
# Out:
# 2026-05-22 23:19:57,794 | INFO | build_pipeline | Pipeline (encoder, scaler, classifier) created for model: K-Nearest Neighbors.

# %%
# Building Support Vector Machine model
pipe_SVM=build_pipeline('Support Vector Machine')
fitted_pipe_SVM=pipe_SVM.fit(X_train, y_train)
# Out:
# 2026-05-22 23:19:57,820 | INFO | build_pipeline | Pipeline (encoder, scaler, classifier) created for model: Support Vector Machine.

# %%
# Building Decision Tree model
pipe_DT=build_pipeline('Decision Tree')
fitted_pipe_DT=pipe_DT.fit(X_train, y_train)
# Out:
# 2026-05-22 23:20:01,216 | INFO | build_pipeline | Pipeline (encoder, scaler, classifier) created for model: Decision Tree.

# %%
# Building Random Forest model
pipe_RF=build_pipeline('Random Forest')
fitted_pipe_RF=pipe_RF.fit(X_train, y_train)
# Out:
# 2026-05-22 23:20:01,264 | INFO | build_pipeline | Pipeline (encoder, scaler, classifier) created for model: Random Forest.

# %%
# Evaluate model performance
metrics_LR=evaluate_model(fitted_pipe_LR,X_test,y_test)
print(metrics_LR['report'])
# Out:
# 2026-05-22 23:20:01,731 | INFO | evaluate_model | Calculated accuracy, roc_auc, f_1, precision, recall, average_precision, confusion_matrix and report for LogisticRegression classification model.
#               precision    recall  f1-score   support
#
#    Not Churn       0.85      0.90      0.87      1033
#        Churn       0.67      0.55      0.60       374
#
#     accuracy                           0.81      1407
#    macro avg       0.76      0.73      0.74      1407
# weighted avg       0.80      0.81      0.80      1407

# %%
metrics_KNN=evaluate_model(fitted_pipe_KNN,X_test,y_test)
print(metrics_KNN['report'])
# Out:
# 2026-05-22 23:20:01,809 | INFO | evaluate_model | Calculated accuracy, roc_auc, f_1, precision, recall, average_precision, confusion_matrix and report for KNeighborsClassifier classification model.
#               precision    recall  f1-score   support
#
#    Not Churn       0.83      0.86      0.84      1033
#        Churn       0.57      0.52      0.54       374
#
#     accuracy                           0.77      1407
#    macro avg       0.70      0.69      0.69      1407
# weighted avg       0.76      0.77      0.76      1407

# %%
metrics_SVM=evaluate_model(fitted_pipe_SVM,X_test,y_test)
print(metrics_SVM['report'])
# Out:
# 2026-05-22 23:20:02,168 | INFO | evaluate_model | Calculated accuracy, roc_auc, f_1, precision, recall, average_precision, confusion_matrix and report for SVC classification model.
#               precision    recall  f1-score   support
#
#    Not Churn       0.83      0.93      0.88      1033
#        Churn       0.70      0.48      0.57       374
#
#     accuracy                           0.81      1407
#    macro avg       0.77      0.70      0.72      1407
# weighted avg       0.80      0.81      0.80      1407

# %%
metrics_DT=evaluate_model(fitted_pipe_DT,X_test,y_test)
print(metrics_DT['report'])
# Out:
# 2026-05-22 23:20:02,197 | INFO | evaluate_model | Calculated accuracy, roc_auc, f_1, precision, recall, average_precision, confusion_matrix and report for DecisionTreeClassifier classification model.
#               precision    recall  f1-score   support
#
#    Not Churn       0.81      0.81      0.81      1033
#        Churn       0.48      0.48      0.48       374
#
#     accuracy                           0.72      1407
#    macro avg       0.64      0.64      0.64      1407
# weighted avg       0.72      0.72      0.72      1407

# %%
metrics_RF=evaluate_model(fitted_pipe_RF,X_test,y_test)
print(metrics_RF['report'])
# Out:
# 2026-05-22 23:20:02,267 | INFO | evaluate_model | Calculated accuracy, roc_auc, f_1, precision, recall, average_precision, confusion_matrix and report for RandomForestClassifier classification model.
#               precision    recall  f1-score   support
#
#    Not Churn       0.83      0.90      0.86      1033
#        Churn       0.64      0.48      0.55       374
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.69      0.70      1407
# weighted avg       0.78      0.79      0.78      1407

# %%
# Save trained model
'''
path_LR = Path(MODEL_PATH/"Logistic_Regression")
path_LR.mkdir(exist_ok=True)
joblib.dump(fitted_pipe_LR, path_LR/"model_LR.pkl")

path_KNN = Path(MODEL_PATH/"K_Nearest_Neighbors")
path_KNN.mkdir(exist_ok=True)
joblib.dump(fitted_pipe_KNN, path_KNN/"model_KNN.pkl")

path_SVM = Path(MODEL_PATH/"Support_Vector_Machine")
path_SVM.mkdir(exist_ok=True)
joblib.dump(fitted_pipe_SVM, path_SVM/"model_SVM.pkl")

path_DT = Path(MODEL_PATH/"Decision_Tree")
path_DT.mkdir(exist_ok=True)
joblib.dump(fitted_pipe_DT, path_DT/"model_DT.pkl")

path_RF = Path(MODEL_PATH/"Random_Forest")
path_RF.mkdir(exist_ok=True)
joblib.dump(fitted_pipe_RF, path_RF/"model_RF.pkl")
'''
